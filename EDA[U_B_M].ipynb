# %%
df=pd.read_csv("irisdata.csv")
df.head(2)
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa

# %%
df.shape
# Out:
# (150, 5)

# %% [markdown]
# # Univariate analysis

# %%
df_setosa=df.loc[df.Species=='setosa'].head(2)
df_versicolor=df.loc[df.Species=='versicolor'].head(2)
df_virginica=df.loc[df.Species=='virginica'].head(2)

# %%
df.Species[45:55]
# Out:
# 45        setosa
# 46        setosa
# 47        setosa
# 48        setosa
# 49        setosa
# 50    versicolor
# 51    versicolor
# 52    versicolor
# 53    versicolor
# 54    versicolor
# Name: Species, dtype: object

# %%
plt.plot(df_setosa['Sepal.Length'],np.zeros_like(df_setosa['Sepal.Length']),'o')
plt.plot(df_versicolor['Sepal.Length'],np.zeros_like(df_versicolor['Sepal.Length']),'o')
plt.plot(df_virginica['Sepal.Length'],np.zeros_like(df_virginica['Sepal.Length']),'o')

# %%
df.columns
# Out:
# Index(['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width',
#        'Species'],
#       dtype='object')

# %% [markdown]
# #bivariate analysis

# %%
sns.FacetGrid(df,hue="Species", size=5). map(plt.scatter, 'Sepal.Length','Sepal.Width').add_legend()
# Out:
# C:\Users\ashish\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Multivairate analysis

# %%
sns.pairplot(df,hue="Species", size=3)
# Out:
# C:\Users\ashish\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)
